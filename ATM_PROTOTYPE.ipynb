# %%
# ATM Prototype:
import sys
import xlrd
import xlwt
from xlutils.copy import copy
def Main():
    while True:
        print("Welcome To Bank Management System")
        print()
        print("1 -- Administrator Login\n2 -- User Login")
        user_input = int(input("Enter The Value: "))
        if user_input == 1:
            Admin_login()
            break
        elif user_input == 2:
            User_login()
            break
        else:
            print("Oops!!! Enter the Value from the Above metioned Data")
            Main()

    
def Admin_login():
    while True:
        global user_name
        user_name = input("Enter Your Username: ")
        file_location = "/Users/Raunak Kumar/TECHVANTO (ML Training) 4-6 week/Mini_Projects/users_cred.xls"
        workbook = xlrd.open_workbook(file_location)
        sheet = workbook.sheet_by_index(1)
        admins = []      
        for row in range(sheet.nrows-1):
            admins.append(sheet.cell_value(row+1,0)) # Fetching list of admins and storing in admins [] list:::
        if user_name in admins:
            passw = int(input("Enter Your Password: "))
            user_indx_val = admins.index(user_name)
            get_pass = sheet.row_values(user_indx_val+1)
            if passw in get_pass:
                print("Welcome To The Admin Portal : ",user_name)
                Operations_admin()
                break
            else:
                print("Oops!! Wrong Password!!!")
                
        else:
            print("Oops!! Wrong UserName!!!")

    
def Operations_admin():
    while True:
        print()
        print("Welcome To Admin Operations Control Unit")
        print("1 -- Show Details of The Users\n2 -- Add The User\n3 -- Remove The User\n4 -- Log Out")
        val = int(input("Enter The Value: "))
        if val == 1:
            print()
            Retrieve_det_of_user()
            break
        elif val == 2:
            Add_user()
            break
        elif val == 3:
            Remove_user()
            break
        elif val == 4:
            print()
            print("Logged Out Successfully\nThank You\nVisit Again")
            break
            break
        else:
            print("Oops!!! Enter the Value from the Above metioned Data")

        
def Retrieve_det_of_user():
    while True:
        print("Welcome To View The User")
        file_location = "/Users/Raunak Kumar/TECHVANTO (ML Training) 4-6 week/Mini_Projects/users_cred.xls"
        workbook = xlrd.open_workbook(file_location)
        sheet = workbook.sheet_by_index(0)
        print("Here is The list of Users Registered in The Bank")
        print()
        for row in range(sheet.nrows):
            for col in range(sheet.ncols):
                if col == 2 and row != 0:
                    raw_value = sheet.cell_value(row,col)
                    if raw_value != "--":
                        print(raw_value,end = " ")
                else:
                    if sheet.cell_value(row,col) != "--":
                        print(sheet.cell_value(row,col),end = ' ')
                        print('\t\t',end = ' ')
            print()
        val = input("Want to Go back to Admins Control Unit: ")
        if val == 'yes' or val == 'y' or val == 'Yes' or val == 'Y':
            Operations_admin()
            break
        elif val == 'No' or val == 'no' or val == 'n' or val == 'N':
            break
        
def Add_user():
    i = 0
    while True:
        print("Welcome To Add The User")
        new_user = input("Enter The New USERS User Name: ")
        new_pass = int(input("Enter The New USERS Password: "))
        amt = float(input("Enter The Amount: "))
        rb = xlrd.open_workbook('/Users/Raunak Kumar/TECHVANTO (ML Training) 4-6 week/Mini_Projects/users_cred.xls')
        sheet = rb.sheet_by_index(0)
        wb = copy(rb)
        w_sheet = wb.get_sheet(0)
        x = sheet.nrows
        print(x)
        w_sheet.write(x+i,0,new_user)
        w_sheet.write(x+i,1,new_pass)
        w_sheet.write(x+i,2,amt)
        wb.save('/Users/Raunak Kumar/TECHVANTO (ML Training) 4-6 week/Mini_Projects/users_cred.xls')
        print("User Added Successfully")
        val = input("Want to Continue Yes or No: ")
        if val == 'yes' or val == 'y' or val == 'Yes' or val == 'Y':
            print()
        elif val == 'No' or val == 'no' or val == 'n' or val == 'N':
            Operations_admin()
            break
    
    
    
    
def Remove_user():
    while True:
        user = input("Enter USERS User_Name to Remove the Data")
        file_location = "/Users/Raunak Kumar/TECHVANTO (ML Training) 4-6 week/Mini_Projects/users_cred.xls"
        workbook = xlrd.open_workbook(file_location)
        sheet = workbook.sheet_by_index(0)
        users = []      
        for row in range(sheet.nrows-1):
            users.append(sheet.cell_value(row+1,0)) # Fetching list of users and storing in admins [] list:::
        rb = xlrd.open_workbook('/Users/Raunak Kumar/TECHVANTO (ML Training) 4-6 week/Mini_Projects/users_cred.xls')
        wb = copy(rb)
        w_sheet = wb.get_sheet(0)
        user_indx_val = users.index(user)
        w_sheet.write(user_indx_val+1,0,'--')
        w_sheet.write(user_indx_val+1,1,'--')
        w_sheet.write(user_indx_val+1,2,'--')
        wb.save('/Users/Raunak Kumar/TECHVANTO (ML Training) 4-6 week/Mini_Projects/users_cred.xls')
        print("User Removed Successfully")
        val = input("Want to Continue Yes or No: ")
        if val == 'yes' or val == 'y' or val == 'Yes' or val == 'Y':
            print()
        elif val == 'No' or val == 'no' or val == 'n' or val == 'N':
            Operations_admin()
            break
        
def User_login():
    while True:
        global user_name
        user_name = input("Enter Your Username: ")
        file_location = "/Users/Raunak Kumar/TECHVANTO (ML Training) 4-6 week/Mini_Projects/users_cred.xls"
        workbook = xlrd.open_workbook(file_location)
        sheet = workbook.sheet_by_index(0)
        users = []      
        for row in range(sheet.nrows-1):
            users.append(sheet.cell_value(row+1,0)) # Fetching list of admins and storing in admins [] list:::
        if user_name in users:
            passw = int(input("Enter Your Password: "))
            user_indx_val = users.index(user_name)
            get_pass = sheet.row_values(user_indx_val+1)
            if passw in get_pass:
                print("Welcome To The User Portal : ",user_name)
                Operations_user()
                break
            else:
                print("Oops!! Wrong Password!!!")
                
        else:
            print("Oops!! Wrong UserName!!!")
        
def Operations_user():
    while True:
        print()
        print("Welcome To Users Operations Control Unit")
        print("1 -- Deposit Money\n2 -- Transfer Money\n3 -- Pin Change\n4 -- Cash Withdrawl\n5 -- Balance Enquiry\n6 -- Log Out")
        val = int(input("Enter The Value: "))
        if val == 1:
            print()
            Deposit_money()
            break
        elif val == 2:
            Transfer_money()
            break
        elif val == 3:
            Pin_change()
            break
        elif val == 4:
            Cash_withdrawl()
            break
        elif val == 5:
            Balance_enquiry()
            break
        elif val == 6:
            print()
            print("Logged Out Successfully\nThank You\nVisit Again")
            break
        else:
            print("Oops!!! Enter the Value from the Above metioned Data")
    
        
        
def Deposit_money():
    while True:
        amt = float(input("Enter The Amount To Deposit: "))
        file_location = "/Users/Raunak Kumar/TECHVANTO (ML Training) 4-6 week/Mini_Projects/users_cred.xls"
        workbook = xlrd.open_workbook(file_location)
        sheet = workbook.sheet_by_index(0)
        users = []      
        for row in range(sheet.nrows-1):
            users.append(sheet.cell_value(row+1,0)) # Fetching list of admins and storing in admins [] list:::
        user_indx_val = users.index(user_name)
        rb = xlrd.open_workbook('/Users/Raunak Kumar/TECHVANTO (ML Training) 4-6 week/Mini_Projects/users_cred.xls')
        wb = copy(rb)
        w_sheet = wb.get_sheet(0)
        prev_amt = sheet.cell_value(user_indx_val+1,2)
        tot_amt = prev_amt + amt
        w_sheet.write(user_indx_val+1,2,tot_amt)
        wb.save('/Users/Raunak Kumar/TECHVANTO (ML Training) 4-6 week/Mini_Projects/users_cred.xls')
        print("Money Deposited Successfully")
        val = input("Want to Continue Yes or No: ")
        if val == 'yes' or val == 'y' or val == 'Yes' or val == 'Y':
            print()
        elif val == 'No' or val == 'no' or val == 'n' or val == 'N':
            Operations_user()
            break
        

def Transfer_money():
    while True:
        amt = float(input("Enter The Amount To Transfer: "))
        file_location = "/Users/Raunak Kumar/TECHVANTO (ML Training) 4-6 week/Mini_Projects/users_cred.xls"
        workbook = xlrd.open_workbook(file_location)
        sheet = workbook.sheet_by_index(0)
        users = []      
        for row in range(sheet.nrows-1):
            users.append(sheet.cell_value(row+1,0)) # Fetching list of admins and storing in admins [] list:::
        user_indx_val = users.index(user_name)
        balance = sheet.cell_value(user_indx_val+1,2)
        print("Your Current Balance is: ",balance)
        if float(amt) < float(balance):
            recipient = input("Enter the Recipient User Name: ")
            file_location = "/Users/Raunak Kumar/TECHVANTO (ML Training) 4-6 week/Mini_Projects/users_cred.xls"
            workbook = xlrd.open_workbook(file_location)
            sheet = workbook.sheet_by_index(0)
            users = []      
            for row in range(sheet.nrows-1):
                users.append(sheet.cell_value(row+1,0)) # Fetching list of admins and storing in admins [] list:::
            user_indx_val = users.index(user_name)
            user_indx_recip = users.index(recipient)
            rb = xlrd.open_workbook('/Users/Raunak Kumar/TECHVANTO (ML Training) 4-6 week/Mini_Projects/users_cred.xls')
            wb = copy(rb)
            w_sheet = wb.get_sheet(0)
            amt_add = sheet.cell_value(user_indx_recip+1,2)
            tot_amt = amt_add + amt
            w_sheet.write(user_indx_recip+1,2,tot_amt)
            amt_subtr = sheet.cell_value(user_indx_val+1,2)
            tot_amt = amt_subtr - amt
            w_sheet.write(user_indx_val+1,2,tot_amt)
            wb.save('/Users/Raunak Kumar/TECHVANTO (ML Training) 4-6 week/Mini_Projects/users_cred.xls')
            print("Money Deposited Successfully")
            val = input("Want to Continue Yes or No: ")
            if val == 'yes' or val == 'y' or val == 'Yes' or val == 'Y':
                print()
            elif val == 'No' or val == 'no' or val == 'n' or val == 'N':
                Operations_user()
                break  
        else:
            print("Insufficient Balance!! Kindly Check Your balance and then Continue with the Transaction: ")
        
        
def Pin_change():
    while True:
        old_pin = int(input("Enter Your Old Pin: "))
        file_location = "/Users/Raunak Kumar/TECHVANTO (ML Training) 4-6 week/Mini_Projects/users_cred.xls"
        workbook = xlrd.open_workbook(file_location)
        sheet = workbook.sheet_by_index(0)
        users = []      
        for row in range(sheet.nrows-1):
            users.append(sheet.cell_value(row+1,0)) # Fetching list of admins and storing in admins [] list:::
        user_indx_val = users.index(user_name)
        pin = sheet.cell_value(user_indx_val+1,1)
        if old_pin == pin:
            new_pin = int(input("Enter Your New Pin: "))
            rb = xlrd.open_workbook('/Users/Raunak Kumar/TECHVANTO (ML Training) 4-6 week/Mini_Projects/users_cred.xls')
            wb = copy(rb)
            w_sheet = wb.get_sheet(0)
            w_sheet.write(user_indx_val+1,1,new_pin)
            wb.save('/Users/Raunak Kumar/TECHVANTO (ML Training) 4-6 week/Mini_Projects/users_cred.xls')
            print("Pin Changed Successfully\nLogging Out\nYou need To Login Again")
            User_login()
        else:
            print("Oops!! Wrong Pin Kindly Check and Try again!!!")
            print()
            
def Cash_withdrawl():
    while True:
        amt = float(input("Enter The Amount To Withdraw: "))
        file_location = "/Users/Raunak Kumar/TECHVANTO (ML Training) 4-6 week/Mini_Projects/users_cred.xls"
        workbook = xlrd.open_workbook(file_location)
        sheet = workbook.sheet_by_index(0)
        users = []      
        for row in range(sheet.nrows-1):
            users.append(sheet.cell_value(row+1,0)) # Fetching list of admins and storing in admins [] list:::
        user_indx_val = users.index(user_name)
        balance = sheet.cell_value(user_indx_val+1,2)
        if float(amt) < float(balance):
            file_location = "/Users/Raunak Kumar/TECHVANTO (ML Training) 4-6 week/Mini_Projects/users_cred.xls"
            workbook = xlrd.open_workbook(file_location)
            sheet = workbook.sheet_by_index(0)
            users = []      
            for row in range(sheet.nrows-1):
                users.append(sheet.cell_value(row+1,0)) # Fetching list of admins and storing in admins [] list:::
            user_indx_val = users.index(user_name)
            rb = xlrd.open_workbook('/Users/Raunak Kumar/TECHVANTO (ML Training) 4-6 week/Mini_Projects/users_cred.xls')
            wb = copy(rb)
            w_sheet = wb.get_sheet(0)
            amt_cur = sheet.cell_value(user_indx_val+1,2)
            tot_amt = amt_cur - amt
            w_sheet.write(user_indx_val+1,2,tot_amt)
            wb.save('/Users/Raunak Kumar/TECHVANTO (ML Training) 4-6 week/Mini_Projects/users_cred.xls')
            print("Cash Withdrawn Successfully")
            val = input("Want to Continue Yes or No: ")
            if val == 'yes' or val == 'y' or val == 'Yes' or val == 'Y':
                print()
            elif val == 'No' or val == 'no' or val == 'n' or val == 'N':
                Operations_user()
                break  
        else:
            print("Insufficient Balance!! Kindly Check Your balance and then Continue with the Transaction: ")
    
    
    

def Balance_enquiry():
    file_location = "/Users/Raunak Kumar/TECHVANTO (ML Training) 4-6 week/Mini_Projects/users_cred.xls"
    workbook = xlrd.open_workbook(file_location)
    sheet = workbook.sheet_by_index(0)
    users = []      
    for row in range(sheet.nrows-1):
        users.append(sheet.cell_value(row+1,0)) # Fetching list of admins and storing in admins [] list:::
    user_indx_val = users.index(user_name)
    balance = sheet.cell_value(user_indx_val+1,2)
    print("Your Current Balance is: ",balance)
    val = input("Want to Go back to Users Control Unit: ")
    if val == 'yes' or val == 'y' or val == 'Yes' or val == 'Y':
        print()
        Operations_user()
    elif val == 'No' or val == 'no' or val == 'n' or val == 'N':
        sys.exit("Logging Out-------")  
    
    
    
    
    
    
        
Main()



#Deposit_money()
# Out:
# Welcome To Bank Management System
#
# 1 -- Administrator Login
# 2 -- User Login
# Enter The Value: 1
# Enter Your Username: admin
# Oops!! Wrong UserName!!!
# Enter Your Username: raunak_kumar2110
# Oops!! Wrong UserName!!!
# Enter Your Username: raunak_kumar
# Enter Your Password: 2121
# Welcome To The Admin Portal :  raunak_kumar
#
# Welcome To Admin Operations Control Unit
# 1 -- Show Details of The Users
# 2 -- Add The User
# 3 -- Remove The User
# 4 -- Log Out
# Enter The Value: 1
#
# Welcome To View The User
# Here is The list of Users Registered in The Bank
#
# User_Name 		 Password 		 Amount
# raunak_kumar 		 2121.0 		 997.0
# ayushi_sharma 		 1242.0 		 12002.0
# shivam_singh 		 1232.0 		 2000.0
# payal 		 2321.0 		 321.0
# shaym 		 2424.0 		 321.0
#
#
# sonam 		 3213.0 		 2313.0
# Want to Go back to Admins Control Unit: y
#
# Welcome To Admin Operations Control Unit
# 1 -- Show Details of The Users
# 2 -- Add The User
# 3 -- Remove The User
# 4 -- Log Out
# ...
